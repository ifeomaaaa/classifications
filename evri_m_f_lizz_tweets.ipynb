# %%
import tweepy as tw
from textblob import TextBlob
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
consumer_key= 'insert'
consumer_secret= 'insert'
access_token= 'insert'
access_token_secret= 'insert'

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# %% [markdown]
# Males

# %%
user_info = api.get_user("lateefsaka")
print(user_info)
# Out:
# User(_api=<tweepy.api.API object at 0x7fc949af5150>, _json={'id': 110224423, 'id_str': '110224423', 'name': 'Lateef', 'screen_name': 'LateefSaka', 'location': 'Paris/London', 'profile_location': None, 'description': 'Skin care | Art | Travel | Finance | featured in @MTVUK @yahoostyleuk @glamourmag @Guardian @Buzzfeeduk // SOAS, Warwick Grad', 'url': 'https://t.co/61UN4acQrS', 'entities': {'url': {'urls': [{'url': 'https://t.co/61UN4acQrS', 'expanded_url': 'http://youtube.com/lateefsaka', 'display_url': 'youtube.com/lateefsaka', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 26748, 'friends_count': 2542, 'listed_count': 93, 'created_at': 'Sun Jan 31 20:13:39 +0000 2010', 'favourites_count': 32339, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 67985, 'lang': None, 'status': {'created_at': 'Thu Sep 08 02:42:07 +0000 2022', 'id': 1567704810115186688, 'id_str': '1567704810115186688', 'text': 'Help… I’m with people who like fish pie.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 10, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1545878532835917825/axPwESfo_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1545878532835917825/axPwESfo_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/110224423/1590767776', 'profile_link_color': '12CEE3', 'profile_sidebar_border_color': '0A010A', 'profile_sidebar_fill_color': '030103', 'profile_text_color': '0013E3', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, id=110224423, id_str='110224423', name='Lateef', screen_name='LateefSaka', location='Paris/London', profile_location=None, description='Skin care | Art | Travel | Finance | featured in @MTVUK @yahoostyleuk @glamourmag @Guardian @Buzzfeeduk // SOAS, Warwick Grad', url='https://t.co/61UN4acQrS', entities={'url': {'urls': [{'url': 'https://t.co/61UN4acQrS', 'expanded_url': 'http://youtube.com/lateefsaka', 'display_url': 'youtube.com/lateefsaka', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=26748, friends_count=2542, listed_count=93, created_at=datetime.datetime(2010, 1, 31, 20, 13, 39), favourites_count=32339, utc_offset=None, time_zone=None, geo_enabled=True, verified=True, statuses_count=67985, lang=None, status=Status(_api=<tweepy.api.API object at 0x7fc949af5150>, _json={'created_at': 'Thu Sep 08 02:42:07 +0000 2022', 'id': 1567704810115186688, 'id_str': '1567704810115186688', 'text': 'Help… I’m with people who like fish pie.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': No ...

# %%
user = "lateefsaka"

# %%
tweets = tw.Cursor(api.user_timeline,
                   screen_name = user,
                   count = None,
                   since_id = None,
                   max_id = None, trim_user = True, exclude_retweets = True, contributor_details = False,
                   include_entities = False).items(2000);

# %%
df = pd.DataFrame(data =[tweet.text for tweet in tweets], columns = ["Tweet"])

# %%
df["Gender"] = "M"  
df["User"] = 'LateefSaka'
df.head()
# Out:
#                                                Tweet Gender        User
# 0  @Chartheegreat Everyone is mad, so you too hav...      M  LateefSaka
# 1               @MzJojoB No but there is no need pls      M  LateefSaka
# 2                         @oyinkanza Can you imagine      M  LateefSaka
# 3  @SephoraCB_x A house you don’t live in? Let’s ...      M  LateefSaka
# 4  @Stuckinlondon1 100%. The age must equal respe...      M  LateefSaka

# %%
import re
def cleaner(txt):
  txt = re.sub(r'@[A-Za-z0-9_]+', '',txt)
  txt = re.sub(r'#', '', txt)
  txt = re.sub(r'RT : ', '', txt)
  txt = re.sub(r"http\S+", "", txt) #removed URL!

  return txt

df["clean"] = df["Tweet"].map(lambda x: cleaner(x))

# %%
df.head()
# Out:
#                                                Tweet Gender        User  \
# 0  @Chartheegreat Everyone is mad, so you too hav...      M  LateefSaka
# 1               @MzJojoB No but there is no need pls      M  LateefSaka
# 2                         @oyinkanza Can you imagine      M  LateefSaka
# 3  @SephoraCB_x A house you don’t live in? Let’s ...      M  LateefSaka
# 4  @Stuckinlondon1 100%. The age must equal respe...      M  LateefSaka
#
#                                                clean
# 0   Everyone is mad, so you too have treat everyo...
# 1                        No but there is no need pls
# 2                                    Can you imagine
# 3   A house you don’t live in? Let’s all respect ...
# 4   100%. The age must equal respect gets me beca...

# %%
df.to_csv('lateefevri.csv')
from google.colab import files
files.download('lateefevri.csv')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
all_words = ' '.join([text for text in df['clean']])
from wordcloud import WordCloud
wordcloud = WordCloud(background_color = 'white', width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure( figsize=(20,10) )
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
user1 = "jameshullF1"

tweets = tw.Cursor(api.user_timeline,
                   screen_name = user,
                   count = None,
                   since_id = None,
                   max_id = None, trim_user = True, exclude_retweets = True, contributor_details = False,
                   include_entities = False).items(2000);

df1 = pd.DataFrame(data =[tweet.text for tweet in tweets], columns = ["Tweet"])
df1["Gender"] = "M"  
df1["User"] = 'James Hull'
df1.head()
# Out:
#                                                Tweet Gender        User
# 0           Help… I’m with people who like fish pie.      M  James Hull
# 1  @jurassicpatek I think rhaenys may have caught...      M  James Hull
# 2          @EnClaudeNeuf The laziness was ridiculous      M  James Hull
# 3  @A_sh1101 I won’t even watch it. I need Martin...      M  James Hull
# 4  @Tonestiger That man has tasted money, we aren...      M  James Hull

# %%
def cleaner(txt):
  txt = re.sub(r'@[A-Za-z0-9_]+', '',txt)
  txt = re.sub(r'#', '', txt)
  txt = re.sub(r'RT : ', '', txt)
  txt = re.sub(r"http\S+", "", txt) #removed URL!

  return txt

df1["clean"] = df1["Tweet"].map(lambda x: cleaner(x))

# %%
df1.to_csv('jamesevri.csv')
from google.colab import files
files.download('jamesevri.csv')

# %%
user2 = "TweetsByBilal"

tweets = tw.Cursor(api.user_timeline,
                   screen_name = user,
                   count = None,
                   since_id = None,
                   max_id = None, trim_user = True, exclude_retweets = True, contributor_details = False,
                   include_entities = False).items(2000);

df2 = pd.DataFrame(data =[tweet.text for tweet in tweets], columns = ["Tweet"])
df2["Gender"] = "M"  
df2["User"] = 'Bilal'
df2.head()
# Out:
#                                                Tweet Gender   User
# 0           Help… I’m with people who like fish pie.      M  Bilal
# 1  @jurassicpatek I think rhaenys may have caught...      M  Bilal
# 2          @EnClaudeNeuf The laziness was ridiculous      M  Bilal
# 3  @A_sh1101 I won’t even watch it. I need Martin...      M  Bilal
# 4  @Tonestiger That man has tasted money, we aren...      M  Bilal

# %%
def cleaner(txt):
  txt = re.sub(r'@[A-Za-z0-9_]+', '',txt)
  txt = re.sub(r'#', '', txt)
  txt = re.sub(r'RT : ', '', txt)
  txt = re.sub(r"http\S+", "", txt) #removed URL!

  return txt

df2["clean"] = df2["Tweet"].map(lambda x: cleaner(x))

# %%
df2.to_csv('bilalevri.csv')
from google.colab import files
files.download('bilalevri.csv')

# %%
user3 = "Matthew74289583"

tweets = tw.Cursor(api.user_timeline,
                   screen_name = user,
                   count = None,
                   since_id = None,
                   max_id = None, trim_user = True, exclude_retweets = True, contributor_details = False,
                   include_entities = False).items(2000);

df3 = pd.DataFrame(data =[tweet.text for tweet in tweets], columns = ["Tweet"])
df3["Gender"] = "M"  
df3["User"] = 'Matthew Jones'
df3.head()
# Out:
#                                                Tweet Gender           User
# 0           Help… I’m with people who like fish pie.      M  Matthew Jones
# 1  @jurassicpatek I think rhaenys may have caught...      M  Matthew Jones
# 2          @EnClaudeNeuf The laziness was ridiculous      M  Matthew Jones
# 3  @A_sh1101 I won’t even watch it. I need Martin...      M  Matthew Jones
# 4  @Tonestiger That man has tasted money, we aren...      M  Matthew Jones

# %%
def cleaner(txt):
  txt = re.sub(r'@[A-Za-z0-9_]+', '',txt)
  txt = re.sub(r'#', '', txt)
  txt = re.sub(r'RT : ', '', txt)
  txt = re.sub(r"http\S+", "", txt) #removed URL!

  return txt

df3["clean"] = df3["Tweet"].map(lambda x: cleaner(x))

# %%
df3.to_csv('matthewevri.csv')
from google.colab import files
files.download('matthewevri.csv')

# %%
user4 = "theshmelaarr"

tweets = tw.Cursor(api.user_timeline,
                   screen_name = user,
                   count = None,
                   since_id = None,
                   max_id = None, trim_user = True, exclude_retweets = True, contributor_details = False,
                   include_entities = False).items(2000);

df4 = pd.DataFrame(data =[tweet.text for tweet in tweets], columns = ["Tweet"])
df4["Gender"] = "M"  
df4["User"] = 'Schmelar'
df4.head()
# Out:
#                                                Tweet Gender      User
# 0           Help… I’m with people who like fish pie.      M  Schmelar
# 1  @jurassicpatek I think rhaenys may have caught...      M  Schmelar
# 2          @EnClaudeNeuf The laziness was ridiculous      M  Schmelar
# 3  @A_sh1101 I won’t even watch it. I need Martin...      M  Schmelar
# 4  @Tonestiger That man has tasted money, we aren...      M  Schmelar

# %%
def cleaner(txt):
  txt = re.sub(r'@[A-Za-z0-9_]+', '',txt)
  txt = re.sub(r'#', '', txt)
  txt = re.sub(r'RT : ', '', txt)
  txt = re.sub(r"http\S+", "", txt) #removed URL!

  return txt

df4["clean"] = df4["Tweet"].map(lambda x: cleaner(x))

# %%
df4.to_csv('schmelarevri.csv')
from google.colab import files
files.download('schmelarevri.csv')

# %% [markdown]
# Females

# %%
user_info = api.get_user("maryannnotmary")
print(user_info)
# Out:
# User(_api=<tweepy.api.API object at 0x7fc59400ba50>, _json={'id': 3387692489, 'id_str': '3387692489', 'name': 'MaryAnn 🌸', 'screen_name': 'maryannnotmary', 'location': 'London', 'profile_location': None, 'description': 'It’s all God 🤸🏾 @farailondon \U0001f90d', 'url': 'https://t.co/ePgWvrvuZX', 'entities': {'url': {'urls': [{'url': 'https://t.co/ePgWvrvuZX', 'expanded_url': 'http://Instagram.com/okaymaryann', 'display_url': 'Instagram.com/okaymaryann', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 20173, 'friends_count': 834, 'listed_count': 43, 'created_at': 'Wed Jul 22 17:54:43 +0000 2015', 'favourites_count': 9740, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 10131, 'lang': None, 'status': {'created_at': 'Tue Sep 06 10:13:29 +0000 2022', 'id': 1567093622419460096, 'id_str': '1567093622419460096', 'text': 'Styles which didn’t make the cut but now I’m like hmmmm thoughts? (Pink is backless) | @FaraiLondon https://t.co/A7z7aAbwkf', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'FaraiLondon', 'name': 'Farai London', 'id': 1277900048140042245, 'id_str': '1277900048140042245', 'indices': [87, 99]}], 'urls': [], 'media': [{'id': 1567093360896229377, 'id_str': '1567093360896229377', 'indices': [100, 123], 'media_url': 'http://pbs.twimg.com/media/Fb9vG-IXwAEBqAV.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Fb9vG-IXwAEBqAV.jpg', 'url': 'https://t.co/A7z7aAbwkf', 'display_url': 'pic.twitter.com/A7z7aAbwkf', 'expanded_url': 'https://twitter.com/maryannnotmary/status/1567093622419460096/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 510, 'h': 680, 'resize': 'fit'}, 'large': {'w': 1536, 'h': 2048, 'resize': 'fit'}, 'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1567093360896229377, 'id_str': '1567093360896229377', 'indices': [100, 123], 'media_url': 'http://pbs.twimg.com/media/Fb9vG-IXwAEBqAV.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Fb9vG-IXwAEBqAV.jpg', 'url': 'https://t.co/A7z7aAbwkf', 'display_url': 'pic.twitter.com/A7z7aAbwkf', 'expanded_url': 'https://twitter.com/maryannnotmary/status/1567093622419460096/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 510, 'h': 680, 'resize': 'fit'}, 'large': {'w': 1536, 'h': 2048, 'resize': 'fit'}, 'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}}, {'id': 1567093411072589826, 'id_str': '1567093411072589826', 'indices': [100, 123], 'media_url': 'http://pbs.twimg.com/media/Fb9vJ5DWQAI0Hqe.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Fb9vJ5DWQAI0Hqe.jpg', 'url': 'https://t.co/A7z7aAbwkf', 'display_url': 'pic.twitter.com/A7z7aAbwkf', 'expanded_url': 'https://twitter.com/maryannnotmary/status/1567093622419460096/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 510, 'h': 680, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 1536, 'h': 2048, 'resize': 'fit'}}}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 24, 'favorite_count': 394, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg. ...

# %%
user5 = "maryannnotmary"

# %%
tweets = tw.Cursor(api.user_timeline,
                   screen_name = user2,
                   count = None,
                   since_id = None,
                   max_id = None, trim_user = True, exclude_retweets = True, contributor_details = False,
                   include_entities = False).items(2000);

df5 = pd.DataFrame(data =[tweet.text for tweet in tweets], columns = ["Tweet"])
df5["Gender"] = "F"  
df5["User"] = 'Maryann'
df5.head()
# Out:
#                                                Tweet Gender     User
# 0  My friend really thought Beyoncé was in danger...      F  Maryann
# 1  She really met Liz Truss one time and this hap...      F  Maryann
# 2  Is there a way to vote Charles out of being King?      F  Maryann
# 3  One thing I’ll never understand is why the Que...      F  Maryann
# 4                             Bank Holiday soon come      F  Maryann

# %%
import re
def cleaner(txt):
  txt = re.sub(r'@[A-Za-z0-9_]+', '',txt)
  txt = re.sub(r'#', '', txt)
  txt = re.sub(r'RT : ', '', txt)
  txt = re.sub(r"http\S+", "", txt) #removed URL!

  return txt

df5["clean"] = df5["Tweet"].map(lambda x: cleaner(x))

# %%
df5.to_csv('maryannevri.csv')
from google.colab import files
files.download('maryannevri.csv')

# %%
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud
from wordcloud import STOPWORDS

# %%
stop_words = STOPWORDS.update(["ve", "t", "s", "v", "m", "gt"])

# %%
all_words = ' '.join([text for text in df1['clean']])
wordcloud = WordCloud(stopwords = stop_words, background_color = 'purple', width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure( figsize=(20,10) )
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
user6 = "slimelia"

tweets = tw.Cursor(api.user_timeline,
                   screen_name = user2,
                   count = None,
                   since_id = None,
                   max_id = None, trim_user = True, exclude_retweets = True, contributor_details = False,
                   include_entities = False).items(2000);

df6 = pd.DataFrame(data =[tweet.text for tweet in tweets], columns = ["Tweet"])
df6["Gender"] = "F"  
df6["User"] = 'Alice Lia'
df6.head()
# Out:
#                                                Tweet Gender       User
# 0  My friend really thought Beyoncé was in danger...      F  Alice Lia
# 1  She really met Liz Truss one time and this hap...      F  Alice Lia
# 2  Is there a way to vote Charles out of being King?      F  Alice Lia
# 3  One thing I’ll never understand is why the Que...      F  Alice Lia
# 4                             Bank Holiday soon come      F  Alice Lia

# %%
def cleaner(txt):
  txt = re.sub(r'@[A-Za-z0-9_]+', '',txt)
  txt = re.sub(r'#', '', txt)
  txt = re.sub(r'RT : ', '', txt)
  txt = re.sub(r"http\S+", "", txt) #removed URL!

  return txt

df6["clean"] = df6["Tweet"].map(lambda x: cleaner(x))

# %%
df6.to_csv('aliceevri.csv')
from google.colab import files
files.download('aliceevri.csv')

# %%
user7 = "aliceetches"

tweets = tw.Cursor(api.user_timeline,
                   screen_name = user2,
                   count = None,
                   since_id = None,
                   max_id = None, trim_user = True, exclude_retweets = True, contributor_details = False,
                   include_entities = False).items(2000);

df7 = pd.DataFrame(data =[tweet.text for tweet in tweets], columns = ["Tweet"])
df7["Gender"] = "F"  
df7["User"] = 'Alice Etches'
df7.head()
# Out:
#                                                Tweet Gender          User
# 0  My friend really thought Beyoncé was in danger...      F  Alice Etches
# 1  She really met Liz Truss one time and this hap...      F  Alice Etches
# 2  Is there a way to vote Charles out of being King?      F  Alice Etches
# 3  One thing I’ll never understand is why the Que...      F  Alice Etches
# 4                             Bank Holiday soon come      F  Alice Etches

# %%
def cleaner(txt):
  txt = re.sub(r'@[A-Za-z0-9_]+', '',txt)
  txt = re.sub(r'#', '', txt)
  txt = re.sub(r'RT : ', '', txt)
  txt = re.sub(r"http\S+", "", txt) #removed URL!

  return txt

df7["clean"] = df7["Tweet"].map(lambda x: cleaner(x))

# %%
df7.to_csv('etchesevri.csv')
from google.colab import files
files.download('etchesevri.csv')

# %%
user8 = "thebellower"

tweets = tw.Cursor(api.user_timeline,
                   screen_name = user2,
                   count = None,
                   since_id = None,
                   max_id = None, trim_user = True, exclude_retweets = True, contributor_details = False,
                   include_entities = False).items(2000);

df8 = pd.DataFrame(data =[tweet.text for tweet in tweets], columns = ["Tweet"])
df8["Gender"] = "F"  
df8["User"] = 'Charlene'
df8.head()
# Out:
#                                                Tweet Gender      User
# 0  My friend really thought Beyoncé was in danger...      F  Charlene
# 1  She really met Liz Truss one time and this hap...      F  Charlene
# 2  Is there a way to vote Charles out of being King?      F  Charlene
# 3  One thing I’ll never understand is why the Que...      F  Charlene
# 4                             Bank Holiday soon come      F  Charlene

# %%
def cleaner(txt):
  txt = re.sub(r'@[A-Za-z0-9_]+', '',txt)
  txt = re.sub(r'#', '', txt)
  txt = re.sub(r'RT : ', '', txt)
  txt = re.sub(r"http\S+", "", txt) #removed URL!

  return txt

df8["clean"] = df8["Tweet"].map(lambda x: cleaner(x))

# %%
df8.to_csv('chareleneevri.csv')
from google.colab import files
files.download('chareleneevri.csv')

# %%
user9 = "YesMissMurphy"

tweets = tw.Cursor(api.user_timeline,
                   screen_name = user2,
                   count = None,
                   since_id = None,
                   max_id = None, trim_user = True, exclude_retweets = True, contributor_details = False,
                   include_entities = False).items(2000);

df9 = pd.DataFrame(data =[tweet.text for tweet in tweets], columns = ["Tweet"])
df9["Gender"] = "F"  
df9["User"] = 'Murphy'
df9.head()
# Out:
#                                                Tweet Gender    User
# 0  My friend really thought Beyoncé was in danger...      F  Murphy
# 1  She really met Liz Truss one time and this hap...      F  Murphy
# 2  Is there a way to vote Charles out of being King?      F  Murphy
# 3  One thing I’ll never understand is why the Que...      F  Murphy
# 4                             Bank Holiday soon come      F  Murphy

# %%
def cleaner(txt):
  txt = re.sub(r'@[A-Za-z0-9_]+', '',txt)
  txt = re.sub(r'#', '', txt)
  txt = re.sub(r'RT : ', '', txt)
  txt = re.sub(r"http\S+", "", txt) #removed URL!

  return txt

df9["clean"] = df9["Tweet"].map(lambda x: cleaner(x))

# %%
df9.to_csv('murphyevri.csv')
from google.colab import files
files.download('murphyevri.csv')
